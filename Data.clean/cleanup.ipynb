# %%
import pandas as pd

# %%
df = pd.read_excel("../Data.clean/project3datavisexcel.xlsx")

# %%
df.head
# Out:
# <bound method NDFrame.head of          Month  Mining  Federal government  Real estate rental and leasing  \
# 0   2008-01-01   17000               15000                           56000
# 1   2008-02-01   17000               13000                           47000
# 2   2008-03-01   14000                8000                           41000
# 3   2008-04-01   15000               10000                           53000
# 4   2008-05-01   14000                7000                           32000
# ..         ...     ...                 ...                             ...
# 127 2018-08-01   21000               13000                           66000
# 128 2018-09-01   21000               16000                           50000
# 129 2018-10-01   19000               16000                           47000
# 130 2018-11-01   20000               18000                           35000
# 131 2018-12-01   21000               21000                           31000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Month                                       132 non-null    datetime64[ns]
#  1   Mining                                      132 non-null    int64
#  2   Federal government                          132 non-null    int64
#  3   Real estate rental and leasing              132 non-null    int64
#  4   Educational services                        132 non-null    int64
#  5   Information                                 132 non-null    int64
#  6   Arts, entertainment, and recreation         132 non-null    int64
#  7   Finance and insurance                       132 non-null    int64
#  8   Wholesale trade                             132 non-null    int64
#  9   Transportation, warehousing, and utilities  132 non-null    int64
# ...

# %%
df.head(5)
# Out:
#        Month  Mining  Federal government  Real estate rental and leasing  \
# 0 2008-01-01   17000               15000                           56000
# 1 2008-02-01   17000               13000                           47000
# 2 2008-03-01   14000                8000                           41000
# 3 2008-04-01   15000               10000                           53000
# 4 2008-05-01   14000                7000                           32000
#
#    Educational services  Information  Arts, entertainment, and recreation  \
# 0                 35000        43000                                62000
# 1                 34000        46000                                54000
# 2                 29000        38000                                46000
# 3                 30000        41000                                50000
# 4                 38000        39000                                52000
#
#    Finance and insurance  Wholesale trade  \
# ...

# %%
# Apply formatting to numeric columns
numeric_cols = df.columns[1:]  # Exclude the 'Month' column
df[numeric_cols] = df[numeric_cols].applymap('{:,.0f}'.format)

df.head(5)
# Out:
#        Month  Mining Federal government Real estate rental and leasing  \
# 0 2008-01-01  17,000             15,000                         56,000
# 1 2008-02-01  17,000             13,000                         47,000
# 2 2008-03-01  14,000              8,000                         41,000
# 3 2008-04-01  15,000             10,000                         53,000
# 4 2008-05-01  14,000              7,000                         32,000
#
#   Educational services Information Arts, entertainment, and recreation  \
# 0               35,000      43,000                              62,000
# 1               34,000      46,000                              54,000
# 2               29,000      38,000                              46,000
# 3               30,000      41,000                              50,000
# 4               38,000      39,000                              52,000
#
#   Finance and insurance Wholesale trade  \
# 0               108,000          94,000
# ...

# %%
df['Month'] = df['Month'].dt.strftime('%Y-%m')
df.head(5)
# Out:
#      Month  Mining Federal government Real estate rental and leasing  \
# 0  2008-01  17,000             15,000                         56,000
# 1  2008-02  17,000             13,000                         47,000
# 2  2008-03  14,000              8,000                         41,000
# 3  2008-04  15,000             10,000                         53,000
# 4  2008-05  14,000              7,000                         32,000
#
#   Educational services Information Arts, entertainment, and recreation  \
# 0               35,000      43,000                              62,000
# 1               34,000      46,000                              54,000
# 2               29,000      38,000                              46,000
# 3               30,000      41,000                              50,000
# 4               38,000      39,000                              52,000
#
#   Finance and insurance Wholesale trade  \
# 0               108,000          94,000
# ...

# %%
df.to_csv('08-18sectordata.csv', index=False)
